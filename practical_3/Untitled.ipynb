# %%
import numpy as np
import matplotlib.pyplot as plt

a = np.array([[1, 174.762],
[1000, 29.8366854731],
[2000, 28.0596815173],
[3000, 27.5659433587],
[4000, 27.7134099452],
[5000, 27.1699680042],
[6000, 26.9978546333],
[7000, 26.8397067642],
[8000, 26.7613489405],
[9000, 26.74049956],
[10000, 26.6938225651],
[11000, 26.6831236966],
[12000, 26.5008902613],
[13000, 26.5934872818],
[14000, 26.3898829365],
[15000, 26.3305090014]])

# %%
plt.plot(a[:,0], a[:,1])
plt.xlabel("step")
plt.ylabel("loss")
plt.xlim((1, 15000))
plt.show()
