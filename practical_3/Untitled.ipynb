# %%
import numpy as np
import matplotlib.pyplot as plt

a = np.loadtxt("a.csv", delimiter=" ")

# %%
plt.plot(a[:,0], a[:,1], alpha=0.2)

b = [  0, 1000,  2001,  3002,  4003,  5004,  6005,   7006,   8007,   9008,
        10009,  11010,  12011,  13012, 
       14013,  15014]

plt.plot(b, a[b,1])

plt.xlabel("step")
plt.ylabel("loss")
plt.xlim((1, 15000))
plt.ylim((5.0, 10.0))
plt.show()

# %%
b = np.where(a[:,0] % 1000 == 0)
print b
# Out:
# (array([  999,  1000,  2000,  2001,  3001,  3002,  4002,  4003,  5003,
#         5004,  6004,  6005,  7005,  7006,  8006,  8007,  9007,  9008,
#        10008, 10009, 11009, 11010, 12010, 12011, 13011, 13012, 14012,
#        14013, 15013, 15014]),)
